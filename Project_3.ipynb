# %%
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import cv2
import easyocr
import json


from pathlib import Path

# %% [markdown]
# # 檔案清單

# %%
cd C:\Yolo_v4\darknet\build\darknet\x64

# %%
# !for %i in (data/obj/*) do echo data/obj/%~nxi>> data/train.txt

# %%
# !for %i in (data/valid/*) do echo data/valid/%~nxi>> data/valid.txt

# %%
# !for %i in (data/test/*) do echo data/test/%~nxi>> data/test.txt

# %%
# !for %i in (data/test_35/*) do echo data/test_35/%~nxi>> data/test_35.txt

# %% [markdown]
# # XML To Txt

# %%
cd C:\Users\MB011B\XmlToTxt

# %%
# !python xmltotxt.py -xml D:\貨櫃資料集\訓練集_xml\ -out C:\Yolo_v4\darknet\build\darknet\x64\data\obj\

# %%
# !python xmltotxt.py -xml D:\貨櫃資料集\驗證集_xml\ -out C:\Yolo_v4\darknet\build\darknet\x64\data\valid\

# %%
# !python xmltotxt.py -xml D:\貨櫃資料集\測試集_xml\ -out C:\Yolo_v4\darknet\build\darknet\x64\data\test\

# %% [markdown]
# # YOLO v4

# %%
cd C:\Yolo_v4\darknet\build\darknet\x64
# Out:
# C:\Yolo_v4\darknet\build\darknet\x64

# %%
#訓練
# !darknet detector train data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg yolov4.conv.137

# %%
#驗證
# !darknet detector valid data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup/yolo-obj_final.weights
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
#  CUDA-version: 10020 (12020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 4.1.0
# results: Using default 'results'
#  0 : compute_capability = 750, cudnn_half = 0, GPU: NVIDIA GeForce RTX 2080 Ti
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
# ...

# %%
#測試
# !darknet detector test data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup/yolo-obj_final.weights < data/test.txt -dont_show -out data/result.txt
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test/image_0001.jpg: Predicted in 15.182000 milli-seconds.
# container: 100%
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test/image_0002.jpg: Predicted in 14.383000 milli-seconds.
# container: 99%
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test/image_0003.jpg: Predicted in 14.418000 milli-seconds.
# container: 99%
# Enter Image Path:  Detection layer: 139 - type = 28
# ...

# %%
# mAP、Recall、Precision和F1-score
# !darknet detector map data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup/yolo-obj_final.weights
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
#
#  calculation mAP (mean average precision)...
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
#
#  detections_count = 1149, unique_truth_count = 755
#  rank = 0 of ranks = 1149
#  rank = 100 of ranks = 1149
#  rank = 200 of ranks = 1149
#  rank = 300 of ranks = 1149
#  rank = 400 of ranks = 1149
#  rank = 500 of ranks = 1149
#  rank = 600 of ranks = 1149
#  rank = 700 of ranks = 1149
#  rank = 800 of ranks = 1149
#  rank = 900 of ranks = 1149
#  rank = 1000 of ranks = 1149
#  rank = 1100 of ranks = 1149
# class_id = 0, name = container, ap = 99.99%   	 (TP = 754, FP = 4)
#
# ...

# %%
#測試_35
# !darknet detector test data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup/yolo-obj_final.weights < data/test_35.txt -dont_show -out data/result_35.txt
# Out:
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test_35/FFAU2895947.jpg: Predicted in 15.550000 milli-seconds.
# container: 99%
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test_35/MAGU5605323.jpg: Predicted in 14.563000 milli-seconds.
# container: 99%
# Enter Image Path:  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# data/test_35/SEKU5875349.jpg: Predicted in 14.495000 milli-seconds.
# container: 99%
# ...

# %%
#測試_video
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0001.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0002.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0003.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0004.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0005.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0006.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0007.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0008.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0009.avi
# !darknet detector demo data/obj.data C:/Yolo_v4/darknet/cfg/yolo-obj.cfg backup\yolo-obj_final.weights -ext_output data\video\video_0010.avi
# Out:
# Demo
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
#  Create cudnn-handle 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 32 K-images (0 Kilo-batches_64)
# video file: data\video\video_0001.avi
# Video stream: 1920 x 1080
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
# container: 83% 	(left_x:  829   top_y:    0   width:  169   height:   62)
#
# FPS:5.1 	 AVG_FPS:0.0
# Objects:
#
# container: 89% 	(left_x:  827   top_y:    0   width:  171   height:   64)
#
# FPS:7.7 	 AVG_FPS:0.0
# Objects:
#
# container: 60% 	(left_x:  830   top_y:    4   width:  164   height:   54)
#
# FPS:10.1 	 AVG_FPS:0.0
# Objects:
#
# container: 69% 	(left_x:  828   top_y:    4   width:  166   height:   54)
#
# FPS:12.2 	 AVG_FPS:0.0
# Objects:
#
# container: 74% 	(left_x:  822   top_y:    4   width:  174   height:   55)
#
# ...

# %% [markdown]
# # 切割物件圖像

# %%
data_dir = "data/test/"
result_file = "data/result.txt"
output_dir = "data/output/"

# 檢查輸出目錄是否存在，如果不存在則建立目錄
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 讀取結果檔案
with open(result_file, 'r') as f:
    results = json.load(f)

# 迭代處理每個結果
for result in results:
    filename = os.path.basename(result['filename'].strip())  # 取得不包含路徑的檔案名稱
    objects = result['objects']

    # 讀取原始影像
    image_path = os.path.join(data_dir, filename)
    image = cv2.imread(image_path)

    # 檢查影像是否成功讀取
    if image is None:
        print(f"無法讀取影像：{image_path}")
        continue

    # 迭代處理每個物件
    for obj in objects:
        class_id = obj['class_id']
        center_x = obj['relative_coordinates']['center_x']
        center_y = obj['relative_coordinates']['center_y']
        width = obj['relative_coordinates']['width']
        height = obj['relative_coordinates']['height']

        # 計算物件在影像中的位置
        left = int((center_x - width/2) * image.shape[1])
        top = int((center_y - height/2) * image.shape[0])
        right = int((center_x + width/2) * image.shape[1])
        bottom = int((center_y + height/2) * image.shape[0])

        # 切割出物件影像
        object_image = image[top:bottom, left:right]

        # 檢查切割的物件影像是否為空
        if object_image.size == 0:
            print(f"空的物件影像：{save_path}")
            continue

        # 儲存物件影像
        object_filename = os.path.splitext(filename)[0] + ".jpg"
        save_path = os.path.join(output_dir, object_filename)
        cv2.imwrite(save_path, object_image)
# Out:
# 空的物件影像：data/output/image_0009.jpg
# 空的物件影像：data/output/image_0023.jpg
# 空的物件影像：data/output/image_0040.jpg
# 空的物件影像：data/output/image_0101.jpg
# 空的物件影像：data/output/image_0127.jpg
# 空的物件影像：data/output/image_0287.jpg
# 空的物件影像：data/output/image_0300.jpg

# %%
data_dir = "data/test_35/"
result_file = "data/result_35.txt"
output_dir = "data/output_35/"

# 檢查輸出目錄是否存在，如果不存在則建立目錄
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 讀取結果檔案
with open(result_file, 'r') as f:
    results = json.load(f)

# 迭代處理每個結果
for result in results:
    filename = os.path.basename(result['filename'].strip())  # 取得不包含路徑的檔案名稱
    objects = result['objects']

    # 讀取原始影像
    image_path = os.path.join(data_dir, filename)
    image = cv2.imread(image_path)

    # 檢查影像是否成功讀取
    if image is None:
        print(f"無法讀取影像：{image_path}")
        continue

    # 迭代處理每個物件
    for obj in objects:
        class_id = obj['class_id']
        center_x = obj['relative_coordinates']['center_x']
        center_y = obj['relative_coordinates']['center_y']
        width = obj['relative_coordinates']['width']
        height = obj['relative_coordinates']['height']

        # 計算物件在影像中的位置
        left = int((center_x - width/2) * image.shape[1])
        top = int((center_y - height/2) * image.shape[0])
        right = int((center_x + width/2) * image.shape[1])
        bottom = int((center_y + height/2) * image.shape[0])

        # 切割出物件影像
        object_image = image[top:bottom, left:right]

        # 檢查切割的物件影像是否為空
        if object_image.size == 0:
            print(f"空的物件影像：{save_path}")
            continue

        # 儲存物件影像
        object_filename = os.path.splitext(filename)[0] + ".jpg"
        save_path = os.path.join(output_dir, object_filename)
        cv2.imwrite(save_path, object_image)

# %% [markdown]
# # OCR

# %%
# this needs to run only once to load the model into memory
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
directory = 'data/output/'

# 取得目錄中的所有文件
files = os.listdir(directory)

# 遍歷每個文件
for file_name in files:
    # 構建文件的完整路徑
    file_path = os.path.join(directory, file_name)
    
    # 檢查是否為檔案而非目錄
    if os.path.isfile(file_path):
        # 進行您的處理
        result = reader.readtext(file_path, detail=0)
        
        # 將結果進行字串處理
        processed_result = ' '.join(result).replace(' ', '')
        
        # 只保留11個字元
        processed_result = processed_result[:11]
        
        # 輸出處理後的結果
        print(file_path, processed_result)
# Out:
# data/output/image_0001.jpg NHSU1665166
# data/output/image_0002.jpg Nu166516614
# data/output/image_0003.jpg YISUl665166
# data/output/image_0004.jpg WHSU6651661
# data/output/image_0005.jpg WHSU1665166
# data/output/image_0006.jpg WhSU6651664
# data/output/image_0007.jpg SEKU|507534
# data/output/image_0008.jpg SEKU|687534
# data/output/image_0009.jpg SEKU|507534
# data/output/image_0010.jpg TSSU#509040
# data/output/image_0011.jpg TSSU5099404
# data/output/image_0012.jpg TSSU:509940
# data/output/image_0013.jpg TSSU|509940
# data/output/image_0014.jpg TSSU|509940
# data/output/image_0015.jpg TSSU5099401
# data/output/image_0016.jpg TSSU|509940
# data/output/image_0017.jpg TSSU5099404
# data/output/image_0018.jpg TSSU"509940
# data/output/image_0019.jpg TSSU5099404
# data/output/image_0020.jpg TSSU:509940
# data/output/image_0021.jpg TSSU|509940
# data/output/image_0022.jpg TSSU|509940
# data/output/image_0023.jpg TSSU|509940
# data/output/image_0024.jpg WHSU5927054
# ...

# %%
directory = 'data/output_35/'

# 取得目錄中的所有文件
files = os.listdir(directory)

# 遍歷每個文件
for file_name in files:
    # 構建文件的完整路徑
    file_path = os.path.join(directory, file_name)
    
    # 檢查是否為檔案而非目錄
    if os.path.isfile(file_path):
        # 進行您的處理
        result = reader.readtext(file_path, detail=0)
        
        # 將結果進行字串處理
        processed_result = ' '.join(result).replace(' ', '')
        
        # 只保留11個字元
        processed_result = processed_result[:11]
        
        # 輸出處理後的結果
        print(file_path, processed_result)
# Out:
# data/output_35/FFAU2895947.jpg FFau2095944
# data/output_35/MAGU5605323.jpg MACU560532B
# data/output_35/SEKU5875349.jpg SEKU|687534
# data/output_35/SEKU5877491.jpg SEKU5877490
# data/output_35/SEKU6026686.jpg SEKU:602668
# data/output_35/TCNU6246126.jpg TCNU6246121
# data/output_35/TLLU4080736.jpg TLLU4080736
# data/output_35/TRHU8927462.jpg TRHU8927462
# data/output_35/TSSU5017340.jpg TSU501734V7
# data/output_35/TSSU5029819.jpg TSSU50298[4
# data/output_35/TSSU5042071.jpg TSSU5042074
# data/output_35/TSSU5061615.jpg TSSU|506161
# data/output_35/TSSU5099400.jpg TSSU5099401
# data/output_35/TSSU5142300.jpg TSSU5142300
# data/output_35/TSSU5160351.jpg TSSU5160354
# data/output_35/WHLU5591798.jpg WHLU5591795
# data/output_35/WHLU5842825.jpg WHLU5842825
# data/output_35/WHSU2483178.jpg 'IHSU240317
# data/output_35/WHSU2615314.jpg WHSU2615312
# data/output_35/WHSU2864765.jpg UuHSU128647
# data/output_35/WHSU5295430.jpg WHSU5295430
# data/output_35/WHSU5368199.jpg WHSU5368190
# ...
